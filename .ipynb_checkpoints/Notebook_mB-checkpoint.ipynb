# %% [markdown]
# # Importaciones y configuraciones
# Importamos las librerías necesarias para realizar cálculos numéricos, manejar el dataset y generar visualizaciones, así como la configuración de los valores para el stratified y minibatch.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# ---------------- Config ----------------
csvPath = "C:/Users/Kevin/Documents/Semestres/II 2025/IA/Tarea 1 Notebook/dataset/Student_Performance.csv"
target_col = "Performance Index"
features = [
    'Hours Studied',
    'Previous Scores',
    'Sample Question Papers Practiced',
    'Sleep Hours',
    'Extracurricular Activities'
]
random_state = 42
train_frac, val_frac, test_frac = 0.70, 0.15, 0.15
batch_size = 64
learning_rate = 1e-3 #esto es 0.001
n_epochs = 50

# %% [markdown]
# # Crear Stratified
# Crear el stratified en terciles

# %%
def crear_strada(df,target,num_cuartiles):
    df['strata'] = pd.qcut(df[target], q=num_cuartiles, labels=False, duplicates='drop') #elimina duplicados en empates (dejar los empates o no?)
    # fallback si quedaron NaN (caso raro)
    if df['strata'].isnull().any():
        print("se genero data NaN")
    else:
        df['strata'] = df['strata'].astype(int)
    # reasignar labels contiguos (0..k-1) por si qcut redujo bins
    unique = sorted(df['strata'].unique())
    mapping = {old:new for new, old in enumerate(unique)}
    df['strata'] = df['strata'].map(mapping).astype(int)
    return df
def separacion_estratificada(df, strata_col='strata', train_frac=0.7, val_frac=0.15, test_frac=0.15, random_state=42):
    assert abs(train_frac + val_frac + test_frac - 1.0) < 1e-8
    train_parts, val_parts, test_parts = [], [], []
    for g, group in df.groupby(strata_col, observed=True):
        group_shuffled = group.sample(frac=1, random_state=random_state).reset_index(drop=True)
        n = len(group_shuffled)
        n_train = int(np.floor(train_frac * n))
        n_val = int(np.floor(val_frac * n))
        # rest -> test
        n_test = n - n_train - n_val
        train_parts.append(group_shuffled.iloc[:n_train])
        val_parts.append(group_shuffled.iloc[n_train:n_train+n_val])
        test_parts.append(group_shuffled.iloc[n_train+n_val:])
    df_train = pd.concat(train_parts, ignore_index=True).sample(frac=1, random_state=random_state).reset_index(drop=True)
    df_val = pd.concat(val_parts, ignore_index=True).sample(frac=1, random_state=random_state).reset_index(drop=True)
    df_test = pd.concat(test_parts, ignore_index=True).sample(frac=1, random_state=random_state).reset_index(drop=True)
    return df_train, df_val, df_test

# %% [markdown]
# # Normalización de los Datos

# %%
def prepare_X_from_stats(df_part, features, featureMeans, featureStds):
    X = df_part[features].to_numpy(dtype=float)
    X_norm = (X - featureMeans) / featureStds
    ones = np.ones((X_norm.shape[0], 1), dtype=float)
    return np.hstack([ones, X_norm])  # intercept + normalized features

# %% [markdown]
# # Generador de mini-batches
# Generador que en cada llamada produce "x" y "y" batches, manteniendo las proporción de los stratos en cada batch aproximadamente.

# %%
def stratifiedMiniBatchGenerator(dfInput, featuresCols, targetColName, stratumColName,
                                 featureMeans, featureStds,
                                 batchSize=32, randomState=42):
    rng = np.random.RandomState(randomState)
    dfShuffled = dfInput.sample(frac=1, random_state=randomState).reset_index(drop=True)

    groupSizes = dfShuffled.groupby(stratumColName, observed=True).size()
    proportions = (groupSizes / len(dfShuffled)).to_dict()  # proporciones por strato

    # convierte el DataFrame en una lista de índices por strato para muestras rápidas
    idxByStratum = {g: dfShuffled[dfShuffled[stratumColName] == g].index.tolist()
                    for g in dfShuffled[stratumColName].unique()}

    pointerByStratum = {g: 0 for g in idxByStratum} # pointer index por strato

    totalRemaining = len(dfShuffled)

    while totalRemaining >= batchSize:
        chosenIndices = []
        for stratum, prop in proportions.items():   # para cada strato, toma la cantidad esperada en el batch
            nExpected = int(round(prop * batchSize))
            availableIndices = idxByStratum[stratum]
            ptr = pointerByStratum[stratum]
            nAvailable = len(availableIndices) - ptr
            nTake = min(nExpected, nAvailable)
            if nTake > 0:
                chosen = availableIndices[ptr: ptr + nTake]
                chosenIndices.extend(chosen)
                pointerByStratum[stratum] += nTake

        # Si por redondeos no alcanza el tamaño del batch, rellena con índices aleatorios de los que quedan
        if len(chosenIndices) < batchSize:
            leftover = []
            for stratum, inds in idxByStratum.items():  # construye lista de todos índices no usados aún
                ptr = pointerByStratum[stratum]
                leftover.extend(inds[ptr:])
            if len(leftover) >= (batchSize - len(chosenIndices)):
                extra = rng.choice(leftover, size=(batchSize - len(chosenIndices)), replace=False).tolist()
                chosenIndices.extend(extra)
            else:   # sale si no hay suficientes leftovers
                break

        
        chosenSet = set(chosenIndices)  # Convierte chosenIndices a conjunto para facilitar
        for stratum in list(idxByStratum.keys()):   # Reconstruye el id por strato eliminando items de chosenSet
            lst = idxByStratum[stratum]
            newLst = [i for i in lst if i not in chosenSet]
            idxByStratum[stratum] = newLst
            pointerByStratum[stratum] = 0  # resetea el pointer

        totalRemaining = sum(len(v) for v in idxByStratum.values())

        # obtiene X_batch, y_batch
        batchDf = dfShuffled.loc[chosenIndices]
        Xb = batchDf[featuresCols].to_numpy(dtype=float)
        yb = batchDf[targetColName].to_numpy(dtype=float).reshape(-1, 1)

        # estandardizamos con los mismos stats y agregamos intercept
        Xb = (Xb - featureMeans) / featureStds
        ones_b = np.ones((Xb.shape[0], 1), dtype=float)
        Xb = np.hstack([ones_b, Xb])

        yield Xb, yb

# %% [markdown]
# ### Carga el csv y lo limpia eliminando duplicados

# %%
df = pd.read_csv('Student_Performance.csv')
df_clean = df.drop_duplicates(keep='first').reset_index(drop=True)

# %% [markdown]
# convierte las categorías relevantes ANTES del split (p.ej. Yes/No -> 1/0)

# %%
if 'Extracurricular Activities' in df_clean.columns:
    df_clean['Extracurricular Activities'] = df_clean['Extracurricular Activities'].map({'Yes':1,'No':0})
df_cuartiles =crear_strada(df_clean,'Performance Index',3)
df_train, df_val, df_test = separacion_estratificada(df_cuartiles, strata_col='strata',train_frac=train_frac, val_frac=val_frac, test_frac=test_frac,random_state=random_state)

# %% [markdown]
# Quita las columnas llamadas strada

# %%
df_train_with_strata = df_train.copy() #se necesita una copia para el for de entrenamiento,con la columna con strada
df_train = df_train.drop(columns=['strata']).reset_index(drop=True)#para el calculo de freaturemeans y freaturestds
df_val   = df_val.drop(columns=['strata']).reset_index(drop=True)
df_test  = df_test.drop(columns=['strata']).reset_index(drop=True)

# %% [markdown]
# Calcula featureMeans/featureStds SOLO sobre df_train

# %%
X_train_raw = df_train[features].to_numpy(dtype=float)
featureMeans = X_train_raw.mean(axis=0)
featureStds  = X_train_raw.std(axis=0, ddof=0)
featureStds[featureStds == 0] = 1.0

# %% [markdown]
# Prepara X_val, X_test. Estos son los datos matriciales validados

# %%
X_val = prepare_X_from_stats(df_val, features, featureMeans, featureStds)
y_val = df_val[target_col].to_numpy(dtype=float).reshape(-1,1)
X_test = prepare_X_from_stats(df_test, features, featureMeans, featureStds)
y_test = df_test[target_col].to_numpy(dtype=float).reshape(-1,1)

# %% [markdown]
# Inicializa pesos (p = n_features + 1)

# %%
p = 1 + len(features)
w = np.zeros((p,1), dtype=float)
train_grafica = []
val_grafica = []

# %% [markdown]
# Entrenamiento usando el generador en el trainining

# %%
for epoch in range(1, n_epochs + 1):
    
    gen = stratifiedMiniBatchGenerator(df_train_with_strata, features, target_col, 'strata',featureMeans, featureStds,batchSize=batch_size, randomState=random_state)
    epoch_losses = []
    for Xb, yb in gen: #calculo de pesos por bache
        m_b = Xb.shape[0]
        yPred = Xb.dot(w)
        err = yPred - yb
        loss = np.mean(err**2)
        epoch_losses.append(loss)
        grad = (2.0 / m_b) * (Xb.T.dot(err))
        w = w - learning_rate * grad

    # calcular val loss (usando X_val preparado con stats de train)
    train_loss = np.mean(epoch_losses)
    val_pred = X_val.dot(w)
    val_loss = np.mean((val_pred - y_val)**2)
    #guardado de datos por epoch
    train_grafica.append(train_loss)
    val_grafica.append(val_loss)

    print(f"Epoch {epoch}/{n_epochs} - MSE_PROMEDIO_TESTIG={np.mean(epoch_losses):.6f}, MSE_PROMEDIO_VALIDACION={val_loss:.6f}")
# Out:
# Epoch 1/50 - MSE_PROMEDIO_TESTIG=2768.487913, MSE_PROMEDIO_VALIDACION=2243.238408
# Epoch 2/50 - MSE_PROMEDIO_TESTIG=1808.836922, MSE_PROMEDIO_VALIDACION=1466.034472
# Epoch 3/50 - MSE_PROMEDIO_TESTIG=1182.365333, MSE_PROMEDIO_VALIDACION=958.616045
# Epoch 4/50 - MSE_PROMEDIO_TESTIG=773.386188, MSE_PROMEDIO_VALIDACION=627.331223
# Epoch 5/50 - MSE_PROMEDIO_TESTIG=506.385205, MSE_PROMEDIO_VALIDACION=411.039835
# Epoch 6/50 - MSE_PROMEDIO_TESTIG=332.069432, MSE_PROMEDIO_VALIDACION=269.826015
# Epoch 7/50 - MSE_PROMEDIO_TESTIG=218.261405, MSE_PROMEDIO_VALIDACION=177.629853
# Epoch 8/50 - MSE_PROMEDIO_TESTIG=143.955768, MSE_PROMEDIO_VALIDACION=117.437282
# Epoch 9/50 - MSE_PROMEDIO_TESTIG=95.439922, MSE_PROMEDIO_VALIDACION=78.139929
# Epoch 10/50 - MSE_PROMEDIO_TESTIG=63.761843, MSE_PROMEDIO_VALIDACION=52.485106
# Epoch 11/50 - MSE_PROMEDIO_TESTIG=43.077208, MSE_PROMEDIO_VALIDACION=35.737460
# Epoch 12/50 - MSE_PROMEDIO_TESTIG=29.570446, MSE_PROMEDIO_VALIDACION=24.805204
# Epoch 13/50 - MSE_PROMEDIO_TESTIG=20.750426, MSE_PROMEDIO_VALIDACION=17.669655
# Epoch 14/50 - MSE_PROMEDIO_TESTIG=14.990675, MSE_PROMEDIO_VALIDACION=13.012778
# Epoch 15/50 - MSE_PROMEDIO_TESTIG=11.229232, MSE_PROMEDIO_VALIDACION=9.974016
# Epoch 16/50 - MSE_PROMEDIO_TESTIG=8.772698, MSE_PROMEDIO_VALIDACION=7.991507
# Epoch 17/50 - MSE_PROMEDIO_TESTIG=7.168305, MSE_PROMEDIO_VALIDACION=6.698423
# Epoch 18/50 - MSE_PROMEDIO_TESTIG=6.120407, MSE_PROMEDIO_VALIDACION=5.855275
# Epoch 19/50 - MSE_PROMEDIO_TESTIG=5.435944, MSE_PROMEDIO_VALIDACION=5.305722
# Epoch 20/50 - MSE_PROMEDIO_TESTIG=4.988842, MSE_PROMEDIO_VALIDACION=4.947708
# Epoch 21/50 - MSE_PROMEDIO_TESTIG=4.696769, MSE_PROMEDIO_VALIDACION=4.714619
# Epoch 22/50 - MSE_PROMEDIO_TESTIG=4.505956, MSE_PROMEDIO_VALIDACION=4.562982
# Epoch 23/50 - MSE_PROMEDIO_TESTIG=4.381286, MSE_PROMEDIO_VALIDACION=4.464431
# Epoch 24/50 - MSE_PROMEDIO_TESTIG=4.299823, MSE_PROMEDIO_VALIDACION=4.400460
# Epoch 25/50 - MSE_PROMEDIO_TESTIG=4.246587, MSE_PROMEDIO_VALIDACION=4.359000
# Epoch 26/50 - MSE_PROMEDIO_TESTIG=4.211793, MSE_PROMEDIO_VALIDACION=4.332181
# Epoch 27/50 - MSE_PROMEDIO_TESTIG=4.189048, MSE_PROMEDIO_VALIDACION=4.314876
# Epoch 28/50 - MSE_PROMEDIO_TESTIG=4.174178, MSE_PROMEDIO_VALIDACION=4.303745
# Epoch 29/50 - MSE_PROMEDIO_TESTIG=4.164453, MSE_PROMEDIO_VALIDACION=4.296614
# Epoch 30/50 - MSE_PROMEDIO_TESTIG=4.158091, MSE_PROMEDIO_VALIDACION=4.292069
# Epoch 31/50 - MSE_PROMEDIO_TESTIG=4.153928, MSE_PROMEDIO_VALIDACION=4.289191
# Epoch 32/50 - MSE_PROMEDIO_TESTIG=4.151203, MSE_PROMEDIO_VALIDACION=4.287386
# Epoch 33/50 - MSE_PROMEDIO_TESTIG=4.149419, MSE_PROMEDIO_VALIDACION=4.286266
# Epoch 34/50 - MSE_PROMEDIO_TESTIG=4.148249, MSE_PROMEDIO_VALIDACION=4.285583
# Epoch 35/50 - MSE_PROMEDIO_TESTIG=4.147482, MSE_PROMEDIO_VALIDACION=4.285176
# Epoch 36/50 - MSE_PROMEDIO_TESTIG=4.146979, MSE_PROMEDIO_VALIDACION=4.284941
# Epoch 37/50 - MSE_PROMEDIO_TESTIG=4.146648, MSE_PROMEDIO_VALIDACION=4.284814
# Epoch 38/50 - MSE_PROMEDIO_TESTIG=4.146430, MSE_PROMEDIO_VALIDACION=4.284751
# Epoch 39/50 - MSE_PROMEDIO_TESTIG=4.146287, MSE_PROMEDIO_VALIDACION=4.284726
# Epoch 40/50 - MSE_PROMEDIO_TESTIG=4.146192, MSE_PROMEDIO_VALIDACION=4.284724
# Epoch 41/50 - MSE_PROMEDIO_TESTIG=4.146129, MSE_PROMEDIO_VALIDACION=4.284733
# Epoch 42/50 - MSE_PROMEDIO_TESTIG=4.146088, MSE_PROMEDIO_VALIDACION=4.284748
# Epoch 43/50 - MSE_PROMEDIO_TESTIG=4.146060, MSE_PROMEDIO_VALIDACION=4.284765
# Epoch 44/50 - MSE_PROMEDIO_TESTIG=4.146041, MSE_PROMEDIO_VALIDACION=4.284781
# Epoch 45/50 - MSE_PROMEDIO_TESTIG=4.146029, MSE_PROMEDIO_VALIDACION=4.284797
# Epoch 46/50 - MSE_PROMEDIO_TESTIG=4.146020, MSE_PROMEDIO_VALIDACION=4.284811
# Epoch 47/50 - MSE_PROMEDIO_TESTIG=4.146015, MSE_PROMEDIO_VALIDACION=4.284823
# Epoch 48/50 - MSE_PROMEDIO_TESTIG=4.146011, MSE_PROMEDIO_VALIDACION=4.284833
# Epoch 49/50 - MSE_PROMEDIO_TESTIG=4.146008, MSE_PROMEDIO_VALIDACION=4.284842
# Epoch 50/50 - MSE_PROMEDIO_TESTIG=4.146006, MSE_PROMEDIO_VALIDACION=4.284849

# %% [markdown]
# ### Graficas de training vs validation de mini batch gradient descent

# %%
plt.figure(figsize=(8,5))
plt.plot(range(1, n_epochs+1), train_grafica, label="Training MSE")
plt.plot(range(1, n_epochs+1), val_grafica, label="Validation MSE")
plt.xlabel("Épocas")
plt.ylabel("MSE")
plt.title("Curvas de aprendizaje: Training vs Validation")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Análisis Final
# Durante el entrenamiento con stratified mini-batch gradient descent, el modelo aprendió rápidamente al principio, reduciendo bastante el error en las primeras 10 épocas. Esto significa que aprendió pronto las relaciones más importantes entre los features y la variable que queríamos predecir.
# Después, la reducción del error se ralentizó y finalmente se estabilizó alrededor de 4 para los datos de entrenamiento y 4.28 para los datos de validación. La cercanía de estos valores indica que el modelo funciona bien tanto con los datos con los que entrenó como con los que no, sin sobreajustarse.
# Usar batches que mantienen la misma distribution de la variable objetivo en cada mini-batch ayudó a que el modelo aprendiera de manera más consistente y no se centrara demasiado en algunos valores más que en otros.
# El entrenamiento fue eficiente y estable, logrando errores bajos y mostrando que esta forma de organizar los mini-batches ayuda a que el modelo aprenda mejor cuando los datos no están completamente balanceados. Los parámetros usados, como el learning rate, el tamaño del batch y el número de épocas, fueron adecuados para que el modelo aprendiera rápido y sin volverse inestable.
